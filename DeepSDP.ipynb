# %% [markdown]
# REACH SDP implementation from author

# %%
import cvxpy as cp

import numpy as np
from scipy.linalg import block_diag

from scipy.special import comb
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import scipy.io
from scipy.io import savemat
from scipy.linalg import block_diag
from scipy import sparse
import torch
import mosek
import time
from NeuralNetwork import NeuralNetwork
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`

# %%
def get_weights(net,save_model=False,file_name='net'):
    '''
    Export pytorch fully connected network to matlab

    '''

    num_layers = int((len(net)-1)/2)
    dim_in = net[0].weight.shape[1]
    dim_out = net[-1].weight.shape[0]
    hidden_dims = [net[2*i].weight.shape[0] for i in range(0,num_layers)]

    # network dimensions
    dims = [dim_in] + hidden_dims + [dim_out]

    # get weights
    weights = np.zeros((num_layers+1,), dtype=np.object)
    weights[:] = [net[2*i].weight.detach().numpy().astype(np.float64) for i in range(0,num_layers+1)]


    # get biases
    biases = np.zeros((num_layers+1,), dtype=np.object)
    biases[:] = [net[2*i].bias.detach().numpy().astype(np.float64).reshape(-1,1) for i in range(0,num_layers+1)]

    activation = str(net[1])[0:-2].lower()

    
    if save_model:
        # export network data to matlab
        data = {}
        data['net'] = {'weights': weights,'biases':biases, 'dims': dims, 'activation': activation, 'name': file_name}

        scipy.io.savemat(file_name + '.mat', data)

        torch.save(net, file_name + '.pt')
    
    return weights, biases, dims


def IBP_relu(weights,biases,dims,x_min,x_max):

    
    pre_activation_lb = np.empty((0,1))
    pre_activation_ub = np.empty((0,1))
    
    post_activation_lb = np.empty((0,1))
    post_activation_ub = np.empty((0,1))

    
    lb = {}
    ub = {}

    lb[0] = x_min
    ub[0] = x_max

    num_layers = len(dims)-2
    num_neurons = sum(dims[1:-1])
    
    

    for i in range(0,num_layers):

        lb[i+1] = np.maximum(0,weights[i])@lb[i] + np.minimum(0,weights[i])@ub[i] + biases[i]
        pre_activation_lb = np.append(pre_activation_lb,lb[i+1])
        

        ub[i+1] = np.maximum(0,weights[i])@ub[i] + np.minimum(0,weights[i])@lb[i] + biases[i]
        pre_activation_ub = np.append(pre_activation_ub,ub[i+1])
        

        lb[i+1] = np.maximum(lb[i+1],0)
        ub[i+1] = np.maximum(ub[i+1],0)
        
        post_activation_lb = np.append(post_activation_lb,lb[i+1])
        post_activation_ub = np.append(post_activation_ub,ub[i+1])
    
    
        
    return post_activation_lb.reshape(num_neurons,1),post_activation_ub.reshape(num_neurons,1)#pre_activation_lb.reshape(num_neurons,1),pre_activation_ub.reshape(num_neurons,1)#,



def generate_sdp_reach(net,x_min,x_max,c, ADynamics=None, BDynamics=None, CDynamics=None):
    
    
    
    x_min_cp = cp.Parameter(x_min.shape)
    x_max_cp = cp.Parameter(x_max.shape)
    c_cp = cp.Parameter(c.shape)
    
    x_min_cp.value = x_min
    x_max_cp.value = x_max
    c_cp.value = c

    
    
    weights, biases, dims = get_weights(net,save_model=False,file_name='net')
    
    dim_in = dims[0]
    dim_out = dims[-1] if ADynamics is None else ADynamics.shape[0]
    num_neurons = sum(dims[1:-1])
    dim_last_hidden = dims[-2]

    
    b_cp = cp.Variable((1,1))
    tau = cp.Variable((dim_in,1),nonneg=True)
    P_in = cp.bmat([[-2*cp.diag(tau),cp.diag(tau)@(x_min+x_max)],[(x_min.T+x_max.T)@cp.diag(tau), -2.0*x_min.T@cp.diag(tau)*x_max]])

    CM_in = np.block([[np.eye(dim_in),np.zeros((dim_in,num_neurons+1))],[np.zeros((1,dim_in+num_neurons)),1]])

    M_in = CM_in.T@P_in@CM_in


    A = block_diag(*weights[0:-1])
    A = np.block([A,np.zeros((A.shape[0],dim_last_hidden))])
    bb = np.concatenate(biases[0:-1],axis=0)
    B = np.block([np.zeros((num_neurons,dim_in)),np.eye(num_neurons)])

    CM_mid = np.block([[A,bb],[B,np.zeros((B.shape[0],1))],[np.zeros((1,B.shape[1])),1]])


    nu = cp.Variable((num_neurons,1),nonneg=True)
    eta = cp.Variable((num_neurons,1),nonneg=True)
    lam = cp.Variable((num_neurons,1))
    mu = cp.Variable((num_neurons,1),nonneg=True)


    lb,ub = IBP_relu(weights,biases,dims,x_min,x_max)
    
    

    Q11 = np.zeros((num_neurons,num_neurons))
    Q12 = cp.diag(lam)
    Q13 = -nu
    Q22 = -2*cp.diag(lam)-2*cp.diag(mu)
    Q23 = eta+nu+cp.diag(mu)@(lb+ub)
    Q33 = np.zeros((1,1))-2*lb.T@cp.diag(mu)*ub

    Q_mid = cp.bmat([[Q11, Q12, Q13],[Q12.T, Q22, Q23],[Q13.T, Q23.T, Q33]])

    M_mid = CM_mid.T@Q_mid@CM_mid
    if ADynamics is None:
        CM_out = np.block([[np.zeros((dim_out,dim_in+num_neurons-dim_last_hidden)), weights[-1], biases[-1]],
                           [np.zeros((1,dim_in+num_neurons)), 1]])
    else:
        if CDynamics is None:
            CDynamics = np.zeros_like(BDynamics @ biases[-1])


        CM_out = np.block([[ADynamics, np.zeros((ADynamics.shape[0], dim_in + num_neurons - ADynamics.shape[1] - weights[-1].shape[1])),
                            BDynamics @ weights[-1], BDynamics @ biases[-1] + CDynamics],
                           [np.zeros((1,dim_in+num_neurons)), 1]])

    S = cp.bmat([[np.zeros((dim_out,dim_out)), c_cp],[c_cp.T, -2*b_cp]])

    M_out = CM_out.T@S@CM_out 

    const = [M_in+M_mid+M_out<<0]

    obj = b_cp

    prob = cp.Problem(cp.Minimize(obj),const)

    
    
    return prob

# %%
fileName = "doubleIntegratorCorrect"
pathToStateDictionary = "Networks/" + fileName +  ".pth"
network = NeuralNetwork(pathToStateDictionary)
net = network.Linear
horizon = 5
A = None
B = None
C = None
if "doubleIntegrator" in pathToStateDictionary:
    A = np.array([[1., 1], [0, 1]])

    B = np.array([[0.5], [1]])
    C = np.array([[0.], [0.]])

    # lowerCoordinate = torch.Tensor([1., 1.5]).to(device)
    # upperCoordinate = torch.Tensor([2., 2.5]).to(device)

    x_min = np.array([[2.5], [-0.25]])
    x_max = np.array([[3.], [0.25]])

# %%
weights, biases, dims = get_weights(net,save_model=True,file_name='net')


cs = np.vstack([np.eye(2), -np.eye(2)])
dataDictionary = {}
for j in range(horizon):
    drawingBounds = []
    for i in range(4):
        c = cs[i:i + 1, :].T
        sdp = generate_sdp_reach(net,x_min,x_max,c, ADynamics=A, BDynamics=B, CDynamics=C)
        sdp.solve(solver=cp.MOSEK,verbose=False,warm_start=True)
        drawingBounds.append([sdp.objective.value])
    dataDictionary[j + 1] = {"A": cs, "d": np.array(drawingBounds)}
    x_max[0] = drawingBounds[0][0]
    x_max[1] = drawingBounds[1][0]
    x_min[0] = -drawingBounds[2][0]
    x_min[1] = -drawingBounds[3][0]
torch.save(dataDictionary, "Output/drawing" + fileName + ".pth")
# Out:
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 1 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 2 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 3 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 4 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 5 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 6 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 7 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 8 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 9 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 10 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 11 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 12 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 13 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 14 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 15 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 16 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 17 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 18 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 19 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 20 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 21 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 22 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 23 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 24 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 25 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 26 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 27 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 28 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 29 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 30 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 31 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 32 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 33 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 34 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 35 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 36 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 37 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 38 times so far.
#
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_651368/1730023611.py:16: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   weights = np.zeros((num_layers+1,), dtype=np.object)
# /tmp/ipykernel_651368/1730023611.py:21: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   biases = np.zeros((num_layers+1,), dtype=np.object)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 39 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/taha/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:593: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 40 times so far.
#
#   warnings.warn(msg, UserWarning)

# %%
ts = time.time()
sdp.solve(solver=cp.SCS,verbose=True,warm_start=True)
print(time.time()-ts,sdp.objective.value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 2
#       1 ts = time.time()
# ----> 2 sdp.solve(solver=cp.SCS,verbose=True,warm_start=True)
#       3 print(time.time()-ts,sdp.objective.value)
#
# NameError: name 'sdp' is not defined

# %%
sdp.objective.value
# Out:
# 1.5679090262263344

# %%
ts = time.time()
sdp.solve(solver=cp.CVXOPT,verbose=True)
print(time.time()-ts,sdp.objective.value)
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0: -2.3555e-01 -7.5878e-01  1e+03  1e+01  7e+01  1e+00
#  1:  2.9903e-01 -4.4780e-01  3e+02  7e+00  3e+01  5e-03
#  2: -5.1050e-02 -1.8510e-01  2e+01  1e+00  7e+00  1e-02
#  3:  3.8142e-01  2.4941e-01  2e+01  1e+00  7e+00  1e-02
#  4:  3.4025e-01  2.1624e-01  2e+01  1e+00  6e+00  2e-02
#  5:  4.8676e-01  3.7610e-01  2e+01  1e+00  6e+00  2e-02
#  6:  7.7571e-01  7.1223e-01  1e+01  7e-01  3e+00  1e-02
#  7:  7.5093e-01  6.8860e-01  1e+01  7e-01  3e+00  1e-02
#  8:  8.4471e-01  7.8850e-01  1e+01  6e-01  3e+00  1e-02
#  9:  1.0322e+00  1.0038e+00  6e+00  3e-01  2e+00  6e-03
# 10:  1.0753e+00  1.0474e+00  6e+00  3e-01  2e+00  6e-03
# 11:  1.3199e+00  1.3035e+00  4e+00  2e-01  9e-01  4e-03
# 12:  1.3621e+00  1.3466e+00  4e+00  2e-01  9e-01  4e-03
# 13:  1.7527e+00  1.7463e+00  2e+00  8e-02  4e-01  2e-03
# 14:  1.7631e+00  1.7567e+00  2e+00  8e-02  4e-01  2e-03
# 15:  1.9217e+00  1.9175e+00  1e+00  5e-02  2e-01  1e-03
# 16:  2.1294e+00  2.1278e+00  5e-01  2e-02  9e-02  4e-04
# 17:  2.1396e+00  2.1381e+00  4e-01  2e-02  9e-02  4e-04
# 18:  2.2518e+00  2.2513e+00  1e-01  6e-03  3e-02  1e-04
# 19:  2.2596e+00  2.2592e+00  1e-01  5e-03  2e-02  1e-04
# 20:  2.3002e+00  2.3001e+00  2e-02  9e-04  4e-03  2e-05
# 21:  2.3043e+00  2.3043e+00  1e-02  5e-04  3e-03  1e-05
# 22:  2.3087e+00  2.3087e+00  3e-03  1e-04  6e-04  3e-06
# 23:  2.3095e+00  2.3095e+00  2e-03  7e-05  3e-04  2e-06
# 24:  2.3101e+00  2.3101e+00  2e-04  7e-06  4e-05  2e-07
# 25:  2.3102e+00  2.3102e+00  5e-05  2e-06  1e-05  5e-08
# 26:  2.3102e+00  2.3102e+00  5e-06  2e-07  1e-06  5e-09
# 27:  2.3102e+00  2.3102e+00  9e-07  4e-08  2e-07  9e-10
# 28:  2.3102e+00  2.3102e+00  1e-07  4e-09  2e-08  1e-10
# Optimal solution found.
# 175.8905050754547 2.310194013999648

# %%
ts = time.time()
sdp.solve(solver=cp.MOSEK,verbose=True,warm_start=True)
print(time.time()-ts,sdp.objective.value)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Sep 12 12:36:59 PM: Your problem has 801 variables, 1 constraints, and 10 parameters.
# (CVXPY) Sep 12 12:36:59 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Sep 12 12:36:59 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Sep 12 12:36:59 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Sep 12 12:36:59 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Sep 12 12:36:59 PM: Applying reduction Dcp2Cone
# (CVXPY) Sep 12 12:36:59 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Sep 12 12:36:59 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Sep 12 12:36:59 PM: Applying reduction MOSEK
# (CVXPY) Sep 12 12:37:04 PM: Finished problem compilation (took 4.760e+00 seconds).
# (CVXPY) Sep 12 12:37:04 PM: (Subsequent compilations of this problem, using the same arguments, should take less time.)
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Sep 12 12:37:04 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Sep 12 12:37:07 PM: Problem
# (CVXPY) Sep 12 12:37:07 PM:   Name                   :
# (CVXPY) Sep 12 12:37:07 PM:   Objective sense        : maximize
# (CVXPY) Sep 12 12:37:07 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Sep 12 12:37:07 PM:   Constraints            : 801
# (CVXPY) Sep 12 12:37:07 PM:   Affine conic cons.     : 0
# (CVXPY) Sep 12 12:37:07 PM:   Disjunctive cons.      : 0
# (CVXPY) Sep 12 12:37:07 PM:   Cones                  : 0
# (CVXPY) Sep 12 12:37:07 PM:   Scalar variables       : 650
# (CVXPY) Sep 12 12:37:07 PM:   Matrix variables       : 1
# (CVXPY) Sep 12 12:37:07 PM:   Integer variables      : 0
# (CVXPY) Sep 12 12:37:07 PM:
# (CVXPY) Sep 12 12:37:07 PM: Optimizer started.
# (CVXPY) Sep 12 12:37:07 PM: src/mosek/mosekco.c(2132): trunctol: 1.000000e-12
# (CVXPY) Sep 12 12:37:07 PM: Presolve started.
# (CVXPY) Sep 12 12:37:07 PM: Linear dependency checker started.
# (CVXPY) Sep 12 12:37:07 PM: Linear dependency checker terminated.
# (CVXPY) Sep 12 12:37:07 PM: Eliminator started.
# (CVXPY) Sep 12 12:37:07 PM: Freed constraints in eliminator : 0
# (CVXPY) Sep 12 12:37:07 PM: Eliminator terminated.
# (CVXPY) Sep 12 12:37:07 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Sep 12 12:37:07 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Sep 12 12:37:07 PM: Lin. dep.  - number                 : 0
# (CVXPY) Sep 12 12:37:07 PM: Presolve terminated. Time: 0.01
# (CVXPY) Sep 12 12:37:07 PM: GP based matrix reordering started.
# (CVXPY) Sep 12 12:37:07 PM: GP based matrix reordering terminated.
# (CVXPY) Sep 12 12:37:07 PM: Problem
# (CVXPY) Sep 12 12:37:07 PM:   Name                   :
# (CVXPY) Sep 12 12:37:07 PM:   Objective sense        : maximize
# (CVXPY) Sep 12 12:37:07 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Sep 12 12:37:07 PM:   Constraints            : 801
# (CVXPY) Sep 12 12:37:07 PM:   Affine conic cons.     : 0
# (CVXPY) Sep 12 12:37:07 PM:   Disjunctive cons.      : 0
# (CVXPY) Sep 12 12:37:07 PM:   Cones                  : 0
# (CVXPY) Sep 12 12:37:07 PM:   Scalar variables       : 650
# (CVXPY) Sep 12 12:37:07 PM:   Matrix variables       : 1
# (CVXPY) Sep 12 12:37:07 PM:   Integer variables      : 0
# (CVXPY) Sep 12 12:37:07 PM:
# (CVXPY) Sep 12 12:37:07 PM: Optimizer  - threads                : 8
# (CVXPY) Sep 12 12:37:07 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Sep 12 12:37:07 PM: Optimizer  - Constraints            : 801
# (CVXPY) Sep 12 12:37:07 PM: Optimizer  - Cones                  : 0
# (CVXPY) Sep 12 12:37:07 PM: Optimizer  - Scalar variables       : 650               conic                  : 0
# (CVXPY) Sep 12 12:37:07 PM: Optimizer  - Semi-definite variables: 1                 scalarized             : 61776
# (CVXPY) Sep 12 12:37:07 PM: Factor     - setup time             : 0.04              dense det. time        : 0.00
# (CVXPY) Sep 12 12:37:07 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Sep 12 12:37:07 PM: Factor     - nonzeros before factor : 3.21e+05          after factor           : 3.21e+05
# (CVXPY) Sep 12 12:37:07 PM: Factor     - dense dim.             : 0                 flops                  : 3.72e+09
# (CVXPY) Sep 12 12:37:07 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Sep 12 12:37:07 PM: 0   1.0e+00  1.0e+00  1.3e+00  0.00e+00   -3.223328590e-01  0.000000000e+00   1.0e+00  0.10
# (CVXPY) Sep 12 12:37:09 PM: 1   7.4e-01  7.4e-01  2.6e-01  9.96e-01   4.079952460e-01   5.746776626e-01   7.4e-01  2.10
# (CVXPY) Sep 12 12:37:11 PM: 2   6.4e-01  6.4e-01  2.6e-01  7.82e-01   6.836535251e-01   8.523749738e-01   6.4e-01  4.05
# (CVXPY) Sep 12 12:37:13 PM: 3   3.2e-01  3.2e-01  6.8e-02  1.44e+00   1.070133845e+00   1.139438898e+00   3.2e-01  5.95
# (CVXPY) Sep 12 12:37:15 PM: 4   2.3e-01  2.3e-01  3.8e-02  1.77e+00   8.505934959e-01   8.937172438e-01   2.3e-01  7.84
# (CVXPY) Sep 12 12:37:17 PM: 5   1.9e-01  1.9e-01  2.7e-02  1.50e+00   7.939175283e-01   8.273354050e-01   1.9e-01  9.71
# (CVXPY) Sep 12 12:37:19 PM: 6   1.9e-01  1.9e-01  2.6e-02  1.28e+00   8.480237288e-01   8.805912056e-01   1.9e-01  11.59
# (CVXPY) Sep 12 12:37:20 PM: 7   1.0e-01  1.0e-01  1.1e-02  1.29e+00   9.315954734e-01   9.486264970e-01   1.0e-01  13.47
# (CVXPY) Sep 12 12:37:22 PM: 8   6.7e-02  6.7e-02  5.8e-03  1.00e+00   1.111530194e+00   1.123326692e+00   6.7e-02  15.39
# (CVXPY) Sep 12 12:37:24 PM: 9   2.1e-02  2.1e-02  9.1e-04  1.02e+00   1.354274295e+00   1.358139834e+00   2.1e-02  17.28
# (CVXPY) Sep 12 12:37:26 PM: 10  9.0e-03  9.0e-03  2.5e-04  9.10e-01   1.465593108e+00   1.467374880e+00   9.0e-03  19.17
# (CVXPY) Sep 12 12:37:28 PM: 11  5.5e-03  5.5e-03  1.2e-04  9.20e-01   1.506275274e+00   1.507395304e+00   5.5e-03  21.05
# (CVXPY) Sep 12 12:37:30 PM: 12  9.2e-04  9.2e-04  7.5e-06  9.73e-01   1.556943898e+00   1.557135165e+00   9.2e-04  22.92
# (CVXPY) Sep 12 12:37:32 PM: 13  2.0e-04  2.0e-04  7.5e-07  1.00e+00   1.565547843e+00   1.565590634e+00   2.0e-04  24.80
# (CVXPY) Sep 12 12:37:34 PM: 14  3.4e-05  3.4e-05  5.2e-08  1.00e+00   1.567616308e+00   1.567623623e+00   3.4e-05  26.69
# (CVXPY) Sep 12 12:37:36 PM: 15  2.3e-06  2.3e-06  9.0e-10  1.00e+00   1.568012294e+00   1.568012793e+00   2.3e-06  28.57
# (CVXPY) Sep 12 12:37:37 PM: 16  1.6e-07  1.6e-07  1.7e-11  1.00e+00   1.568039098e+00   1.568039133e+00   1.6e-07  30.47
# (CVXPY) Sep 12 12:37:39 PM: 17  1.2e-08  1.4e-08  3.4e-13  1.00e+00   1.568040988e+00   1.568040991e+00   1.2e-08  32.35
# (CVXPY) Sep 12 12:37:39 PM: Optimizer terminated. Time: 32.43
# (CVXPY) Sep 12 12:37:39 PM:
# (CVXPY) Sep 12 12:37:39 PM:
# (CVXPY) Sep 12 12:37:39 PM: Interior-point solution summary
# (CVXPY) Sep 12 12:37:39 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Sep 12 12:37:39 PM:   Solution status : OPTIMAL
# (CVXPY) Sep 12 12:37:39 PM:   Primal.  obj: 1.5680409880e+00    nrm: 5e+00    Viol.  con: 5e-09    var: 2e-08    barvar: 0e+00
# (CVXPY) Sep 12 12:37:39 PM:   Dual.    obj: 1.5680409906e+00    nrm: 4e+00    Viol.  con: 0e+00    var: 8e-17    barvar: 3e-09
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Sep 12 12:37:39 PM: Problem status: optimal
# (CVXPY) Sep 12 12:37:39 PM: Optimal value: 1.568e+00
# (CVXPY) Sep 12 12:37:39 PM: Compilation took 4.760e+00 seconds
# (CVXPY) Sep 12 12:37:39 PM: Solver (including time spent in interface) took 3.567e+01 seconds
# 41.15119695663452 1.5680409906206327

# %%
sdp.objective.value
# Out:
# 1.5680409906206327
